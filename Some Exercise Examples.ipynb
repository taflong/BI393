# %% [markdown]
# # Exercise Example 1: Fix this problem

# %%
setwd("/Users/tristanlong/Desktop/R")

# %%
getwd()
# Out:
# [1] "/Users/tristanlong/Desktop/R"

# %%
backpacks<-read.csv("backpacks.csv")

# %%
head(backpacks)
# Out:
#   backpack.weight body.weight Back.problems Sex
# 1  9              125         Yes           Female
# 2  8              195         No            Male
# 3 10              120         Yes           Female
# 4  6              155         No            Male
# 5  8              180         No            Female
# 6  5              240         No            Male

# %% [markdown]
# In your earlier study of student weights and backpacks, you examined whether males and female (and their backpacks) were of similar or different weights using data from Mintz et al. (2004) . Now, we would like to explore the relationship between these variables, and see if this relationship differs between the sexes.
#
# In my hasty analysis of this data, I have used the commands (below)  in R to create a simple (but ugly and uninformative) graph of the relationship between student and their backpacks. _Note that there is nothing that distinguishes males from females in this graph!_

# %%
attach(backpacks)
plot(backpack.weight~body.weight)
abline(lm(backpack.weight~body.weight))
# Out:
# plot without title

# %% [markdown]
# For this assignment, your grade (out of 10) will be based on how well you:
#
# ☐ Fix the figure above to show the relationsiph between backpack and body weights that distinguishes males from females. This includes formatted axes and meaningful labels (2pts).
#
# ☐ Provide a well-written figure legend for both your graph that includes the slope and 	intercept ofProduce a single visually-appealing graph displaying the relationship between body and 	backpack  both the male and the female relationship (3pts).
#
# ☐ Report (in an accompanying paragraph) the results of minimum adequate model for 	your statistical test of the hypothesis that males and females carry different weights 	of backpacks (while taking body weight into account). Be sure to include information relevant to your analysis (i.e. tests of normality, homogeneity of variance etc.., and/or any relevant transformation(s) you performed) (3pts).
#
# ☐Make sure aupi have annotated all the R codes used to generate your graph and calculate your statistics. 	(2pts).
